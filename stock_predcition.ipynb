# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset_path = 'dataset/'

df = pd.read_csv(dataset_path + 'Google_Stock_Price_Train.csv')

#Preview the dataset
print("First 5 Rows of Dataset:")
print(df.head())

# Check dataset info
print("\nDataset Info:")
print(df.info())
# Out:
# First 5 Rows of Dataset:
#        Date    Open    High     Low   Close      Volume
# 0  1/3/2012  325.25  332.83  324.97  663.59   7,380,500
# 1  1/4/2012  331.27  333.87  329.08  666.45   5,749,400
# 2  1/5/2012  329.83  330.75  326.89  657.21   6,590,300
# 3  1/6/2012  328.34  328.77  323.68  648.24   5,405,900
# 4  1/9/2012  322.04  322.29  309.46  620.76  11,688,800
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   object
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   object
# dtypes: float64(3), object(3)
# memory usage: 59.1+ KB
# None

# %%
# Clean the 'Volume' column by removing commas and converting to integers
df['Volume'] = df['Volume'].str.replace(',', '').astype(int)

# Convert 'Date' column to datetime
df['Date'] = pd.to_datetime(df['Date'])

# Preview cleaned data
print("\nCleaned Dataset:")
print(df.head())
# Out:
# Cleaned Dataset:
#         Date    Open    High     Low   Close    Volume
# 0 2012-01-03  325.25  332.83  324.97  663.59   7380500
# 1 2012-01-04  331.27  333.87  329.08  666.45   5749400
# 2 2012-01-05  329.83  330.75  326.89  657.21   6590300
# 3 2012-01-06  328.34  328.77  323.68  648.24   5405900
# 4 2012-01-09  322.04  322.29  309.46  620.76  11688800

# %%
# Check for missing values and data types
print("Training Data Info:")
print(df.info())

print("\nTesting Data Info:")
# print(test_data.info())

# Summary statistics
print("\nTraining Data Description:")
print(df.describe())

# Visualizing the closing price trend
plt.figure(figsize=(12, 6))
plt.plot(df['Date'], df['Close'], label='Closing Price')
plt.title("Stock Closing Price Over Time")
plt.xlabel("Date")
plt.ylabel("Closing Price")
plt.legend()
plt.xticks(rotation=45)
plt.show()
# Out:
# Training Data Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1258 entries, 0 to 1257
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1258 non-null   datetime64[ns]
#  1   Open    1258 non-null   float64
#  2   High    1258 non-null   float64
#  3   Low     1258 non-null   float64
#  4   Close   1258 non-null   object
#  5   Volume  1258 non-null   int64
# dtypes: datetime64[ns](1), float64(3), int64(1), object(1)
# memory usage: 59.1+ KB
# None
#
# Testing Data Info:
#
# Training Data Description:
#                                 Date         Open         High          Low  \
# count                           1258  1258.000000  1258.000000  1258.000000
# mean   2014-07-03 20:00:45.786963456   533.709833   537.880223   529.007409
# min              2012-01-03 00:00:00   279.120000   281.210000   277.220000
# 25%              2013-04-05 18:00:00   404.115000   406.765000   401.765000
# ...

# %%
# Drop unnecessary columns (e.g., 'Date') and handle the volume as numeric
df['Volume'] = df['Volume'].str.replace(',', '').astype(float)
# test_data['Volume'] = test_data['Volume'].str.replace(',', '').astype(float)
from sklearn.preprocessing import MinMaxScaler
# Define features and target for scaling
features = ['Open', 'High', 'Low', 'Close', 'Volume']
target = ['Close']

# Scale data using MinMaxScaler
scaler_features = MinMaxScaler()
scaler_target = MinMaxScaler()

scaled_train_features = scaler_features.fit_transform(df[features])
scaled_train_target = scaler_target.fit_transform(df[target])

# scaled_test_features = scaler_features.transform(test_data[features])
# scaled_test_target = scaler_target.transform(test_data[target])

print("Data scaling completed.")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 # Drop unnecessary columns (e.g., 'Date') and handle the volume as numeric
# ----> 2 df['Volume'] = df['Volume'].str.replace(',', '').astype(float)
#       3 # test_data['Volume'] = test_data['Volume'].str.replace(',', '').astype(float)
#       4 from sklearn.preprocessing import MinMaxScaler
#
# File c:\Users\princ\miniconda3\envs\stock_prediction\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...
